# %% [markdown]
# ## Univariate Time Series Analysis

# %%
from IPython.display import display, Markdown
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import mean_squared_error
plt.style.use('ggplot')

# %%
dic_country = \
{'AUS': 'Australia',
 'BRA': 'Brazil',
 'CAN': 'India',
 'CHN': 'China',
 'GBR': 'United Kingdom',
 'IND': 'India',
 'JPN': 'Japan',
 'SGP': 'Singapore',
 'USA': 'United States'}
pd.DataFrame(dic_country,index=[0]).T.reset_index().rename(columns = {'index': 'country_code', 0: 'country_name'})
# Out:
#   country_code    country_name
# 0          AUS       Australia
# 1          BRA          Brazil
# 2          CAN           India
# 3          CHN           China
# 4          GBR  United Kingdom
# 5          IND           India
# 6          JPN           Japan
# 7          SGP       Singapore
# 8          USA   United States

# %% [markdown]
# ### Import Data

# %%
Data_dic_m = pd.ExcelFile('Manufacturing_filled.xlsx')
Data_dic_s = pd.ExcelFile('Service_filled.xlsx')

# %%
def get_sheet_by_methods(data, method_num, verbose = 0):
  sheet_names = data.sheet_names
  sheet_imputation_map = pd.DataFrame([[s, s[:3].strip(),s[3:]] for s in sheet_names], columns = ['sheet_name', 'country_code', 'imputation method'])
  methods = sheet_imputation_map['imputation method'].unique()
  if verbose:
    print('methods tried:',methods, len(methods))
  return list(sheet_imputation_map.loc[sheet_imputation_map['imputation method'] == methods[method_num]]['sheet_name'].values)

# %%
m_dfs = {}
for i in range(len(Data_dic_m.sheet_names) // 10):
  for sheet in get_sheet_by_methods(Data_dic_m, i):
    df = pd.read_excel(Data_dic_m, sheet_name=sheet)
    df['Year'] = [i.year for i in pd.to_datetime(df.Year, format='%Y')]
    df = df.set_index('Year')
    m_dfs[(sheet[:3], sheet[3:].strip())] = df

# %%
s_dfs = {}
for i in range(len(Data_dic_s.sheet_names) // 10):
  for sheet in get_sheet_by_methods(Data_dic_s, i):
    df = pd.read_excel(Data_dic_s, sheet_name=sheet)
    df['Year'] = [i.year for i in pd.to_datetime(df.Year, format='%Y')]
    df = df.set_index('Year')
    s_dfs[(sheet[:3], sheet[3:].strip())] = df

# %%
# way to retrieve method and country
method = ['Mean','Median','LOCF','NOCB','Rolling statistics']
country = list(dic_country.keys())

m_dfs[(country[0],method[0])] # stands for AUS mean data
# Out:
#       Employment_in_industry_male  Research_development_expenditure  \
# Year
# 1990                    30.583793                          1.949895
# 1991                    31.709999                          1.949895
# 1992                    31.709999                          1.949895
# 1993                    31.670000                          1.949895
# 1994                    31.719999                          1.949895
# 1995                    31.219999                          1.949895
# 1996                    30.610001                          1.663230
# 1997                    30.320000                          1.949895
# 1998                    30.129999                          1.514530
# 1999                    29.760000                          1.949895
# 2000                    30.469999                          1.574240
# 2001                    29.590000                          1.949895
# 2002                    29.920000                          1.748540
# 2003                    29.950001                          1.949895
# 2004                    30.680000                          1.849500
# 2005                    30.650000                          1.949895
# 2006                    31.180000                          2.181130
# 2007                    31.150000                          1.949895
# 2008                    31.660000                          2.401120
# 2009                    31.270000                          1.949895
# 2010                    31.100000                          2.372860
# 2011                    30.969999                          2.235630
# 2012                    30.959999                          1.949895
# 2013                    30.629999                          2.178490
# 2014                    30.530001                          1.949895
# 2002                           10.555349
# 2003                           10.862170
# 2004                           10.882157
# 2005                           10.334862
# 2006                            9.892071
# 2007                            9.290666
# 2008                            9.202199
# 2009                            8.453527
# 2010                            7.997034
# 2011                            7.368513
# 2012                            7.050455
# 2013                            6.608333
# 2014                            6.368635
# 2015                            6.299997
# 2016                            6.085499
# 2017                            5.798737
# 2018                            5.777272
# 2019                            5.615118
# 2020                            5.651114
# 2021                            5.565624

# %% [markdown]
# Since all target variable in our dataset are without missing value. Here for univariate analysis, we will only keep one copy for further analysis.

# %% [markdown]
# ### Get Target Value

# %%
# get target value
manufacture_y = {}
service_y = {}

def get_target_val(df, is_service):
  if not is_service:
    target = df[['Manufacturing_value added_%_of_GDP']]
    target_trim = target[~target['Manufacturing_value added_%_of_GDP'].isna()]
    return target_trim
  else:
    target = df[['Services_value_added_%_of_GDP']]
    target_trim = target[~target['Services_value_added_%_of_GDP'].isna()]
    return target_trim
for con in country: 
  manufacture_y[con] = get_target_val(m_dfs[(con,'Mean')], False)
  service_y[con] = get_target_val(s_dfs[(con,'Mean')], True)

# %%
manufacture_y.keys()
# Out:
# dict_keys(['AUS', 'BRA', 'CAN', 'CHN', 'GBR', 'IND', 'JPN', 'SGP', 'USA'])

# %% [markdown]
# ### Target Value Visualization

# %% [markdown]
# #### Manufacture

# %%
def vis_stationary(df,title,rolling_num = 7):
  fig, axes = plt.subplots(3, 3, dpi=120, figsize=(10,6))
  for i, ax in enumerate(axes.flatten()):
      rolling_mean = df[country[i]].rolling(rolling_num).mean()
      rolling_std = df[country[i]].rolling(rolling_num).std()
      ax.plot(df[country[i]], color="blue",label="Original Target Trend")
      ax.plot(rolling_mean, color="coral", label="Rolling Mean")
      ax.plot(rolling_std, color="black", label = "Rolling Standard Deviation")
      # Decorations
      #ax.seasonal_decompose(df[country],model='additive', period=7)
      ax.xaxis.set_ticks_position('none')
      ax.yaxis.set_ticks_position('none')
      ax.spines["top"].set_alpha(0)
      ax.tick_params(labelsize=6)
      ax.legend(loc="lower left")

  plt.suptitle(title,y=1.05)
  plt.tight_layout()

  plt.show()


vis_stationary(manufacture_y, "Manufacturing_value added_%_of_GDP")

# %% [markdown]
# #### Service

# %%
vis_stationary(service_y, "Services_value_added_%_of_GDP")

# %% [markdown]
# ### Stationarity

# %% [markdown]
# #### Visualization Inspection

# %%
def vis_stationary(df,title,rolling_num = 7):
  fig, axes = plt.subplots(3, 3, dpi=120, figsize=(10,6))
  for i, ax in enumerate(axes.flatten()):
      rolling_mean = df[country[i]].rolling(rolling_num).mean()
      rolling_std = df[country[i]].rolling(rolling_num).std()
      ax.plot(df[country[i]], color="lightblue",label="Original Target Trend")
      ax.plot(rolling_mean, color="coral", label="Rolling Mean")
      ax.plot(rolling_std, color="grey", label = "Rolling Standard Deviation")
      # Decorations
      #ax.seasonal_decompose(df[country],model='additive', period=7)
      ax.xaxis.set_ticks_position('none')
      ax.yaxis.set_ticks_position('none')
      ax.spines["top"].set_alpha(0)
      ax.tick_params(labelsize=6)
      ax.legend(loc="lower left")

  plt.suptitle(title,y=1.05)
  plt.tight_layout()

  plt.show()


vis_stationary(manufacture_y, "Manufacturing_value added_%_of_GDP")

# %%
vis_stationary(service_y, "Services_value_added_%_of_GDP")

# %% [markdown]
# ### ADF test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Cannot reject Null Hypothesis.")
        print(f" => Series is Non-Stationary.")   
    print("\n")

# %%
for con in country:
  adfuller_test(manufacture_y[con],0.05, con)
# Out:
#     Augmented Dickey-Fuller Test on "AUS"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.5292
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.661
#  Critical value 5%     = -2.961
#  Critical value 10%    = -2.619
#  => P-Value = 0.8862. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "BRA"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.516
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.61
#  Critical value 5%     = -2.939
#  Critical value 10%    = -2.608
#  => P-Value = 0.5256. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CAN"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -27.7719
#  No. Lags Chosen       = 9
#  Critical value 1%     = -4.138
#  Critical value 5%     = -3.155
#  Critical value 10%    = -2.714
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CHN"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.5858
#  No. Lags Chosen       = 7
#  Critical value 1%     = -4.332
#  Critical value 5%     = -3.233
#  Critical value 10%    = -2.749
#  => P-Value = 0.4907. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GBR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.9712
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.661
#  Critical value 5%     = -2.961
#  Critical value 10%    = -2.619
#  => P-Value = 0.2994. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "IND"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.4622
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.601
#  Critical value 5%     = -2.935
#  Critical value 10%    = -2.606
#  => P-Value = 0.5521. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "JPN"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.7986
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.711
#  Critical value 5%     = -2.981
#  Critical value 10%    = -2.63
#  => P-Value = 0.3812. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "SGP"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.9912
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.601
#  Critical value 5%     = -2.935
#  Critical value 10%    = -2.606
#  => P-Value = 0.2904. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "USA"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.0669
#  No. Lags Chosen       = 9
#  Critical value 1%     = -4.012
#  Critical value 5%     = -3.104
#  Critical value 10%    = -2.691
#  => P-Value = 0.258. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# #### First Order Difference

# %%
diff_manu = {}
diff_ser = {}
for con in country:
  diff_manu[con] = manufacture_y[con].diff().dropna()
  diff_ser[con] = service_y[con].diff().dropna()

for con in country:
  adfuller_test(diff_manu[con],0.05, con)
# Out:
#     Augmented Dickey-Fuller Test on "AUS"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.3161
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.67
#  Critical value 5%     = -2.964
#  Critical value 10%    = -2.621
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "BRA"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.534
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.61
#  Critical value 5%     = -2.939
#  Critical value 10%    = -2.608
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CAN"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6061
#  No. Lags Chosen       = 8
#  Critical value 1%     = -4.138
#  Critical value 5%     = -3.155
#  Critical value 10%    = -2.714
#  => P-Value = 0.4805. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CHN"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.1605
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.964
#  Critical value 5%     = -3.085
#  Critical value 10%    = -2.682
#  => P-Value = 0.0224. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GBR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.317
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.689
#  Critical value 5%     = -2.972
#  Critical value 10%    = -2.625
#  => P-Value = 0.6214. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "IND"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.7181
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.606
#  Critical value 5%     = -2.937
#  Critical value 10%    = -2.607
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "JPN"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.9904
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.724
#  Critical value 5%     = -2.986
#  Critical value 10%    = -2.633
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "SGP"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.7982
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.606
#  Critical value 5%     = -2.937
#  Critical value 10%    = -2.607
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "USA"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.0072
#  No. Lags Chosen       = 9
#  Critical value 1%     = -4.069
#  Critical value 5%     = -3.127
#  Critical value 10%    = -2.702
#  => P-Value = 0.0342. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# #### Second order difference

# %%
adfuller_test(diff_manu['CAN'].diff().dropna(),0.05, "CAN")
# second-diff of Canada manufature is stationary

adfuller_test(diff_manu['GBR'].diff().dropna(),0.05, "GBR")
# second-diff of Germany manufature is stationary

adfuller_test(diff_ser['CAN'].diff().dropna(),0.05, "CAN")
# second-diff of Canada service still non-stationary, therefore disgard analysis of Canada in service part
# Out:
#     Augmented Dickey-Fuller Test on "CAN"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.3357
#  No. Lags Chosen       = 8
#  Critical value 1%     = -4.223
#  Critical value 5%     = -3.189
#  Critical value 10%    = -2.73
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GBR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.6285
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.689
#  Critical value 5%     = -2.972
#  Critical value 10%    = -2.625
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CAN"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 1.6891
#  No. Lags Chosen       = 8
#  Critical value 1%     = -4.223
#  Critical value 5%     = -3.189
#  Critical value 10%    = -2.73
#  => P-Value = 0.9981. Cannot reject Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# ### Autocorrelation

# %%
print("=======Manufaturing Autocorrelation=======")
for con in country:
  autocorrelation_lag1 =  manufacture_y[con]["Manufacturing_value added_%_of_GDP"].autocorr(lag=1)
  print(f"One Year Lag of {con}: ", autocorrelation_lag1)
print("\n")
print("=======Service Autocorrelation=======")
for con in country:
  autocorrelation_lag1 =  service_y[con]["Services_value_added_%_of_GDP"].autocorr(lag=1)
  print(f"One Year Lag of {con}: ", autocorrelation_lag1)
# Out:
# =======Manufaturing Autocorrelation=======
# One Year Lag of AUS:  0.9924885267251866
# One Year Lag of BRA:  0.9705762022513933
# One Year Lag of CAN:  0.9826457423593227
# One Year Lag of CHN:  0.9586851566326937
# One Year Lag of GBR:  0.9932969057027103
# One Year Lag of IND:  0.8220502897041175
# One Year Lag of JPN:  0.8470591152229123
# One Year Lag of SGP:  0.859512109144477
# One Year Lag of USA:  0.983625139802899
#
#
# =======Service Autocorrelation=======
# One Year Lag of AUS:  0.9184916714686304
# One Year Lag of BRA:  0.891836143786259
# One Year Lag of CAN:  0.8013451362151703
# One Year Lag of CHN:  0.9934692226938163
# One Year Lag of GBR:  0.8225060920740754
# One Year Lag of IND:  0.9871444268079823
# One Year Lag of JPN:  0.969898405687662
# One Year Lag of SGP:  0.9446066751258873
# One Year Lag of USA:  0.8938524099568661

# %% [markdown]
# ### Model Fitting

# %% [markdown]
# #### Train-test split

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.stattools import acf

# %%
def split_train_test(df, valid_num = 5):
    train = df[:-valid_num]
    valid = df[-valid_num:]
    return train, valid

train_manu = {}
valid_manu = {}
train_ser = {}
valid_ser = {}
for con in country:
    train_manu[con], valid_manu[con]= split_train_test(manufacture_y[con])
    train_ser[con], valid_ser[con]= split_train_test(service_y[con])

# %% [markdown]
# ##### ACF and PACF plot

# %%
def show_acf_pacf(df, con, val):
    lag = df[con][val].shape[0]//2 - 1
    plot_acf(df[con][val],lags = lag,title = con + " autocorrelation")
    plot_pacf(df[con][val],lags = lag,title = con + " partial autocorrelation")
for con in country:
    show_acf_pacf(manufacture_y, con, "Manufacturing_value added_%_of_GDP")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# #### AR,MA, ARMA, ARIMA
#
# Performing univariate time series analysis using auto.arima to determine the best practice model.

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (2.0.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)

# %%
from pmdarima.arima import auto_arima
manu_model = {}
ser_model = {}
def set_auto_arima(train, con, manu, dic):
  model = auto_arima(train[con][manu],trace=True, error_action='ignore', suppress_warnings=True)
  model.fit(train[con][manu])
  dic[con] = model

  # forecast = model.predict(n_periods=len(test))
  # forecast = pd.DataFrame(forecast,index = test.index,columns=['Prediction']) 
print("======= Auto ARIMA for manufacture=======")
for con in country:
  print(f"======={con}=======")
  set_auto_arima(train_manu,con, "Manufacturing_value added_%_of_GDP",manu_model)
  print("\n")

print("======= Auto ARIMA for service=======")
for con in country:
  print(f"======={con}=======")
  set_auto_arima(train_ser,con, "Services_value_added_%_of_GDP",ser_model)
  print("\n")
# Out:
# ======= Auto ARIMA for manufacture=======
# =======AUS=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=23.706, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=25.132, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=24.969, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=35.555, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=26.967, Time=0.15 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.918 seconds
#
#
# =======BRA=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=161.436, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=160.229, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=160.738, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=159.279, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=160.432, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=158.589, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=160.098, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=0.58 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.411 seconds
#
#
# =======CAN=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=29.225, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=28.588, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=28.991, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=34.491, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=30.560, Time=0.19 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=30.573, Time=0.31 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=32.426, Time=0.33 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=28.913, Time=0.06 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 1.892 seconds
#
#
# =======CHN=======
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=47.832, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=32.458, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=128.386, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=30.580, Time=0.56 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=1.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.17 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 5.827 seconds
#
#
# =======GBR=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.92 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=23.428, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=25.389, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=25.404, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=35.294, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=26.557, Time=0.31 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 1.626 seconds
#
#
# =======IND=======
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=59.506, Time=1.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=83.055, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=61.699, Time=0.16 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=67.333, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=313.408, Time=0.03 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=62.554, Time=0.90 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=63.410, Time=0.75 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=61.674, Time=1.07 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.96 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=61.923, Time=0.46 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=61.300, Time=0.98 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=62.244, Time=1.05 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=63.107, Time=1.11 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=76.457, Time=0.45 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0] intercept
# Total fit time: 9.153 seconds
#
#
# =======JPN=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.68 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=53.719, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=52.497, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=52.397, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.52 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.113 seconds
#
#
# =======SGP=======
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=141.011, Time=0.45 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=183.670, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=140.227, Time=0.12 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=161.509, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=339.269, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=141.277, Time=0.65 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=141.640, Time=0.42 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=142.062, Time=0.88 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 2.902 seconds
#
#
# =======USA=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.29 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12.071, Time=0.18 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12.137, Time=0.36 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=11.531, Time=0.61 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=19.185, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=13.525, Time=0.59 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=13.523, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=15.242, Time=0.44 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=14.875, Time=0.07 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 3.882 seconds
#
#
# ======= Auto ARIMA for service=======
# =======AUS=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=58.945, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=59.115, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=59.313, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=62.374, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=61.103, Time=0.07 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.572 seconds
#
#
# =======BRA=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=204.632, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=206.625, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=206.624, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=203.557, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.661 seconds
#
#
# =======CAN=======
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=64.522, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=64.964, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=58.930, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=60.668, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=191.388, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=60.882, Time=0.13 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=60.837, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=64.377, Time=0.21 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.901 seconds
#
#
# =======CHN=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=107.519, Time=0.38 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=108.819, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=107.288, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=106.957, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=124.790, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=108.933, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=108.925, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=110.473, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=116.415, Time=0.04 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 0.853 seconds
#
#
# =======GBR=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=89.551, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=91.551, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=91.551, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=87.725, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.529 seconds
#
#
# =======IND=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=79.284, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=81.233, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=81.238, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=87.182, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=83.222, Time=0.08 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.596 seconds
#
#
# =======JPN=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=51.019, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=52.979, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=52.988, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=52.750, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=54.854, Time=0.09 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.502 seconds
#
#
# =======SGP=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=117.033, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=116.346, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=114.500, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=117.337, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=116.138, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=118.029, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=117.576, Time=0.04 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 0.904 seconds
#
#
# =======USA=======
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=34.022, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=38.080, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=39.508, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=38.674, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=39.259, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=40.150, Time=0.05 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=43.373, Time=0.12 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=44.468, Time=0.09 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 2.812 seconds

# %% [markdown]
# #### Forecasting

# %%
forecast = manu_model['CHN'].predict(n_periods=len(valid_manu['CHN'])).reset_index().drop(['index'],axis = 1)
forecast['Year'] = valid_manu['CHN'].index
forecast.set_index(['Year'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
#               0
# Year
# 2017  27.714386
# 2018  27.645154
# 2019  27.725549
# 2020  27.879219
# 2021  28.063819

# %%
forecast_manu = {}
forecast_ser = {}
def forecast_arima(model, valid,con, manu):
  forecast = model.predict(n_periods=len(valid)).reset_index().drop(['index'],axis = 1)
  forecast['Year'] = valid.index
  forecast = forecast.set_index(['Year'])
  forecast = forecast.rename(columns={0: "Prediction"})
  manu[con] = forecast

for con in country:
  forecast_arima(manu_model[con],valid_manu[con],con, forecast_manu)
  forecast_arima(ser_model[con],valid_ser[con],con, forecast_ser)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,

# %%
# for manufaturing
fig, axes = plt.subplots(3, 3, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    ax.plot(train_manu[country[i]],color = "blue",label="Train")
    ax.plot(valid_manu[country[i]],color = "red",label="Valid")
    ax.plot(forecast_manu[country[i]],color = "black",label="Forecast")
    # Decorations
    ax.set_title(country[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=4)
    ax.legend(loc="lower left")

plt.suptitle("Manufacturing_value added_%_of_GDP",y=1.05)
plt.tight_layout()
plt.show()

# %%
# for service
fig, axes = plt.subplots(3, 3, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    ax.plot(train_ser[country[i]],color = "blue",label="Train")
    ax.plot(valid_ser[country[i]],color = "red",label="Valid")
    ax.plot(forecast_ser[country[i]],color = "black",label="Forecast")
    # Decorations
    ax.set_title(country[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=4)
    ax.legend(loc="lower left")

plt.suptitle("Services_value_added_%_of_GDP",y=1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
m_metrics = {}
s_metrics = {}
for con in country:
  mae = mean_absolute_error(valid_manu[con], forecast_manu[con])
  mape = mean_absolute_percentage_error(valid_manu[con],forecast_manu[con])
  rmse = sqrt(mean_squared_error(valid_manu[con],forecast_manu[con]))
  eval = [mae,rmse,mape]
  #print(mae, mse, rmse, con)
  m_metrics[con] = eval

  mae = mean_absolute_error(valid_ser[con], forecast_ser[con])
  mape = mean_absolute_percentage_error(valid_ser[con], forecast_ser[con])
  rmse = sqrt(mean_squared_error(valid_ser[con],forecast_ser[con]))
  eval = [mae,rmse, mape]
  #print(mae, mse, rmse, con)
  s_metrics[con] = eval

# %%
m_eval = pd.DataFrame(m_metrics).transpose()
m_eval.columns = ['MAE', 'RMSE','MAPE']

m_eval
# Out:
#           MAE      RMSE      MAPE
# AUS  0.485452  0.591209  0.086293
# BRA  0.672809  0.806717  0.068163
# CAN  1.360725  1.509589  0.138321
# CHN  0.752271  0.897889  0.028009
# GBR  0.717971  0.798122  0.081627
# IND  1.880092  2.086142  0.135094
# JPN  0.295330  0.382004  0.014768
# SGP  0.922174  1.139728  0.045220
# USA  0.307420  0.365328  0.027437

# %%
s_eval = pd.DataFrame(s_metrics).transpose()
s_eval.columns = ['MAE', 'RMSE','MAPE']

s_eval
# Out:
#           MAE      RMSE      MAPE
# AUS  2.881403  3.021991  0.043524
# BRA  1.010412  1.738805  0.016789
# CAN  2.710705  2.985956  0.040324
# CHN  1.354780  1.691342  0.025292
# GBR  0.565637  0.804392  0.007844
# IND  0.922334  1.129687  0.019037
# JPN  1.228572  1.370898  0.017685
# SGP  1.171764  1.492731  0.016810
# USA  0.880883  1.187005  0.011196
