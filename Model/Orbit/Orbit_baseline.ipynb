# %% [markdown]
# ## Multivariate Time Series Analysis

# %%
from IPython.display import display, Markdown
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
plt.style.use('ggplot')

# %%
# !pip install orbit-ml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting orbit-ml
#   Downloading orbit_ml-1.1.2-py3-none-any.whl (474 kB)
#      |████████████████████████████████| 474 kB 5.6 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from orbit-ml) (1.12.1+cu113)
# Collecting pyro-ppl>=1.4.0
#   Downloading pyro_ppl-1.8.2-py3-none-any.whl (722 kB)
#      |████████████████████████████████| 722 kB 62.5 MB/s
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from orbit-ml) (1.7.3)
# Requirement already satisfied: seaborn>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from orbit-ml) (0.11.2)
# Requirement already satisfied: arviz in /usr/local/lib/python3.7/dist-packages (from orbit-ml) (0.12.1)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.7/dist-packages (from orbit-ml) (1.21.6)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from orbit-ml) (1.3.5)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from orbit-ml) (0.12.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from orbit-ml) (4.64.1)
# Collecting pystan==2.19.1.1
#   Downloading pystan-2.19.1.1-cp37-cp37m-manylinux1_x86_64.whl (67.3 MB)
#      |████████████████████████████████| 67.3 MB 115 kB/s
# Collecting matplotlib>=3.3.2
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 46.6 MB/s
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /usr/local/lib/python3.7/dist-packages (from pystan==2.19.1.1->orbit-ml) (0.29.32)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->orbit-ml) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->orbit-ml) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 64.2 MB/s
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->orbit-ml) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->orbit-ml) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->orbit-ml) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->orbit-ml) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.2->orbit-ml) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.3->orbit-ml) (2022.6)
# Collecting pyro-api>=0.1.1
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from pyro-ppl>=1.4.0->orbit-ml) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.2->orbit-ml) (1.15.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.1->orbit-ml) (0.5.3)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.7/dist-packages (from arviz->orbit-ml) (1.6.1)
# Requirement already satisfied: xarray-einstats>=0.2 in /usr/local/lib/python3.7/dist-packages (from arviz->orbit-ml) (0.2.2)
# Requirement already satisfied: xarray>=0.16.1 in /usr/local/lib/python3.7/dist-packages (from arviz->orbit-ml) (0.20.2)
# Requirement already satisfied: setuptools>=38.4 in /usr/local/lib/python3.7/dist-packages (from arviz->orbit-ml) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from xarray>=0.16.1->arviz->orbit-ml) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->xarray>=0.16.1->arviz->orbit-ml) (3.10.0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.7/dist-packages (from netcdf4->arviz->orbit-ml) (1.6.2)
# Installing collected packages: fonttools, pyro-api, matplotlib, pystan, pyro-ppl, orbit-ml
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: pystan
#     Found existing installation: pystan 3.3.0
#     Uninstalling pystan-3.3.0:
#       Successfully uninstalled pystan-3.3.0
# Successfully installed fonttools-4.38.0 matplotlib-3.5.3 orbit-ml-1.1.2 pyro-api-0.1.2 pyro-ppl-1.8.2 pystan-2.19.1.1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import orbit
from orbit.models import ETS, DLT
from orbit.diagnostics.plot import plot_predicted_data

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %% [markdown]
# ### Import Data

# %%
dic_country = \
{'AUS': 'Australia',
 'BRA': 'Brazil',
 'CAN': 'India',
 'CHN': 'China',
 'GBR': 'United Kingdom',
 'IND': 'India',
 'JPN': 'Japan',
 'SGP': 'Singapore',
 'USA': 'United States'}
pd.DataFrame(dic_country,index=[0]).T.reset_index().rename(columns = {'index': 'country_code', 0: 'country_name'})
# Out:
#   country_code    country_name
# 0          AUS       Australia
# 1          BRA          Brazil
# 2          CAN           India
# 3          CHN           China
# 4          GBR  United Kingdom
# 5          IND           India
# 6          JPN           Japan
# 7          SGP       Singapore
# 8          USA   United States

# %%
Data_dic_m = pd.ExcelFile('Manufacturing_filled.xlsx')
Data_dic_s = pd.ExcelFile('Service_filled.xlsx')

# %%
def get_sheet_by_methods(data, method_num, verbose = 0):
  sheet_names = data.sheet_names
  sheet_imputation_map = pd.DataFrame([[s, s[:3].strip(),s[3:]] for s in sheet_names], columns = ['sheet_name', 'country_code', 'imputation method'])
  methods = sheet_imputation_map['imputation method'].unique()
  if verbose:
    print('methods tried:',methods, len(methods))
  return list(sheet_imputation_map.loc[sheet_imputation_map['imputation method'] == methods[method_num]]['sheet_name'].values)

# %%
m_dfs = {}
for i in range(len(Data_dic_m.sheet_names) // 10):
  for sheet in get_sheet_by_methods(Data_dic_m, i):
    df = pd.read_excel(Data_dic_m, sheet_name=sheet)
    df['Year'] = [i.year for i in pd.to_datetime(df.Year, format='%Y')]
    # df = df.set_index('Year')
    m_dfs[(sheet[:3], sheet[3:].strip())] = df

# %%
s_dfs = {}
for i in range(len(Data_dic_s.sheet_names) // 10):
  for sheet in get_sheet_by_methods(Data_dic_s, i):
    df = pd.read_excel(Data_dic_s, sheet_name=sheet)
    df['Year'] = [i.year for i in pd.to_datetime(df.Year, format='%Y')]
    # df = df.set_index('Year')
    s_dfs[(sheet[:3], sheet[3:].strip())] = df

# %%
# way to retrieve method and country
method = ['Mean','Median','LOCF','NOCB','Rolling statistics']
country = list(dic_country.keys())

m_dfs[('CHN','Rolling statistics')] # stands for AUS mean data
# Out:
#     Year  Employment_in_industry_male  Research_development_expenditure  \
# 0   2004                    23.020000                          1.214980
# 1   2005                    23.818524                          1.265466
# 2   2006                    24.698223                          1.305919
# 3   2007                    25.685230                          1.327484
# 4   2008                    26.430512                          1.359998
# 5   2009                    27.124445                          1.435016
# 6   2010                    27.857034                          1.498120
# 7   2011                    28.598025                          1.557989
# 8   2012                    29.347832                          1.629334
# 9   2013                    29.920328                          1.700559
# 10  2014                    30.368788                          1.760712
# 11  2015                    30.630847                          1.814588
# 12  2016                    30.808488                          1.865391
# 13  2017                    30.869838                          1.909135
# 14  2018                    30.991899                          1.948915
# 15  2019                    30.964423                          1.999101
# 16  2020                    30.964423                          2.066580
# 17  2021                    30.964423                          2.066580
#
#     Researchers in R&D  Population_labor_rate  Population_density  \
# 0           700.070129              71.508852          137.518959
# 1           776.427218              71.864781          137.959601
# 2           830.551835              72.182206          138.409009
# 3           902.766581              72.437777          138.862164
# 4           977.903195              72.627705          139.325914
# 5           945.576872              72.769968          139.800020
# 6           931.769108              72.882186          140.283661
# 7           937.241400              72.956182          140.799189
# 8           952.767565              73.000673          141.380587
# 9           974.692446              73.016184          142.011581
# 10          996.091413              72.994329          142.674733
# 11         1024.226004              72.925233          143.353724
# 12         1054.888301              72.796782          144.046503
# 13         1084.539888              72.608418          144.761678
# 14         1122.796861              72.366705          145.462421
# 15         1181.933677              72.087802          146.125166
# 16         1249.597663              71.790921          146.729441
# 17         1249.597663              71.491374          146.729441
#
#     Foreign_direct_investment  Air_freight_million_ton_km  \
# 0                    3.483641                 7024.250000
# 1                    4.065213                 7325.815583
# 2                    4.239218                 7469.610307
# 3                    4.290687                 8653.317969
# 4                    4.137760                 9403.532641
# 5                    3.751629                10036.776686
# 6                    3.808671                11657.273715
# 7                    3.787491                12740.789341
# 8                    3.594014                13310.494187
# 9                    3.486917                13840.677362
# 10                   3.313547                14584.831710
# 11                   3.109646                15534.143394
# 12                   2.833357                16560.079616
# 13                   2.574316                17740.519417
# 14                   2.422992                19032.304792
# 15                   2.234228                20112.050961
# 16                   2.148408                19969.679281
# 17                   2.148408                19969.679281
#
#     Container_port_traffic_TEU  Industry_value_added_current_USD  \
# 0                 7.472544e+07                      8.975084e+11
# 1                 7.066211e+07                      9.938809e+11
# 2                 7.621485e+07                      1.117492e+12
# 3                 8.499997e+07                      1.291569e+12
# 4                 9.349443e+07                      1.529429e+12
# 5                 9.726143e+07                      1.730059e+12
# 6                 1.051244e+08                      1.979196e+12
# 7                 1.138893e+08                      2.304714e+12
# 8                 1.230450e+08                      2.621174e+12
# 9                 1.329691e+08                      2.931702e+12
# 10                1.427183e+08                      3.227317e+12
# 11                1.519946e+08                      3.461948e+12
# 12                1.601471e+08                      3.636940e+12
# 13                1.709695e+08                      3.858413e+12
# 14                1.816659e+08                      4.143048e+12
# 15                1.919103e+08                      4.375078e+12
# 16                2.008430e+08                      4.573763e+12
# 17                2.008430e+08                      4.976277e+12
#
#     GDP_per_capita_current_USD  Final_consumption  \
# 0                  1508.668098       1.080060e+12
# 1                  1641.619485       1.168687e+12
# 2                  1821.215001       1.277861e+12
# 3                  2098.931919       1.447364e+12
# 4                  2474.863985       1.677799e+12
# 5                  2808.940797       1.893683e+12
# 6                  3203.250677       2.139064e+12
# 7                  3714.737191       2.488820e+12
# 8                  4235.672876       2.866503e+12
# 9                  4773.862549       3.269090e+12
# 10                 5308.772229       3.686450e+12
# 11                 5801.113127       4.102079e+12
# 12                 6208.833819       4.471988e+12
# 13                 6664.034786       4.870342e+12
# 14                 7221.145916       5.348134e+12
# 15                 7717.157456       5.798085e+12
# 16                 8169.141180       6.189137e+12
# 17                 8899.433825       6.189137e+12
#
#     Employment_in_industry_%_of_total_employment  \
# 0                                      22.500000
# 1                                      23.206177
# 2                                      23.988682
# 3                                      24.883263
# 4                                      25.519274
# 5                                      26.080607
# 6                                      26.673685
# 7                                      27.273254
# 8                                      27.883004
# 9                                      28.311481
# 10                                     28.608350
# 11                                     28.712295
# 12                                     28.727888
# 13                                     28.620048
# 14                                     28.568476
# 15                                     28.373568
# 16                                     28.373568
# 17                                     28.373568
#
#     Manufacturing_value added_%_of_GDP
# 0                            31.975070
# 1                            32.039633
# 2                            32.201601
# 3                            32.259436
# 4                            32.220995
# 5                            32.067230
# 6                            31.964344
# 7                            31.985652
# 8                            31.893573
# 9                            31.657289
# 10                           31.421657
# 11                           30.972533
# 12                           30.456388
# 13                           30.046687
# 14                           29.667579
# 15                           29.176631
# 16                           28.691073
# 17                           28.482441

# %% [markdown]
# ### Granger-Causality Test

# %%
# TODO

# %% [markdown]
# ### Train-test split

# %%
def split_train_test(df, valid_num = 5):
    train = df[:-valid_num]
    valid = df[-valid_num:]
    return train, valid

train_manu = {}
valid_manu = {}
train_ser = {}
valid_ser = {}
for m in method:
  for con in country:
    train_manu[(con,m)], valid_manu[(con,m)]= split_train_test(m_dfs[(con,m)])
    train_ser[(con,m)], valid_ser[(con,m)]= split_train_test(s_dfs[(con,m)])

# %% [markdown]
# ###  Exponential Smoothing (ETS)

# %% [markdown]
# #### Maximum a Posteriori (MAP)¶

# %%
forecast_manu = {}
forecast_ser = {}
def fitting_ETS(m, con, response_col, date_col, result, train, test, seasonality = 5,estimator = 'stan-map'):
  ets = ETS(
    response_col=response_col,
    date_col=date_col,
    estimator= estimator,
    # seasonality=seasonality,
    seed=8888,
  )
  ets.fit(df=train[(con,m)])
  predicted_df = ets.predict(df=test[(con,m)])
  result[(con,m)] = predicted_df

# %%
response_col = 'Manufacturing_value added_%_of_GDP'
date_col = 'Year'
for con in country:
  for m in method:
    fitting_ETS(m, con, response_col, date_col, forecast_manu, train_manu, valid_manu)

response_col = 'Services_value_added_%_of_GDP'
date_col = 'Year'
for con in country:
  for m in method:
    fitting_ETS(m, con, response_col, date_col, forecast_ser,train_ser, valid_ser)

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error,mean_absolute_percentage_error

# %%
m_metrics = {}
s_metrics = {}
for m in method:
  for con in country:
    if len(train_manu[(con,m)].columns) > 1 and 'Manufacturing_value added_%_of_GDP' in valid_manu[(con,m)].columns:
      y = valid_manu[(con,m)]['Manufacturing_value added_%_of_GDP']
      yhat = forecast_manu[(con,m)]['prediction']
      mae = mean_absolute_error(y, yhat)
      mape = mean_absolute_percentage_error(y, yhat)
      rmse = sqrt(mean_squared_error(y, yhat))
      eval =  [mae,rmse,mape]
    #print(mae, mse, rmse, con)
      m_metrics[(con,m)] = eval
    elif len(train_manu[(con,m)].columns) == 1:
      print(f'Only contains target variable for service {con} {m}.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]
    else:
      print(f'Target variable for manufaturce {con} {m} is non-stationary.')
      m_metrics[(con,m)] = [np.nan,np.nan,np.nan]

    if  len(train_ser[(con,m)].columns) > 1 and 'Services_value_added_%_of_GDP' in valid_ser[(con,m)].columns:
      y = valid_ser[(con,m)]['Services_value_added_%_of_GDP']
      yhat = forecast_ser[(con,m)]['prediction']
      mae = mean_absolute_error(y, yhat)
      mape = mean_absolute_percentage_error(y, yhat)
      rmse = sqrt(mean_squared_error(y, yhat))
      eval = [mae,rmse,mape]
      #print(mae, mse, rmse, con)
      s_metrics[(con,m)] = eval
    elif len(train_ser[(con,m)].columns) == 1:
      print(f'Only contains target variable for service {con} {m}.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]
    else:
      print(f'Target variable for service {con} {m} is non-stationary.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]

# %%
m_eval = pd.DataFrame(m_metrics).transpose()
m_eval.columns = ['MAE', 'RMSE','MAPE']

m_eval
# Out:
#                              MAE      RMSE      MAPE
# AUS Mean                0.403926  0.414115  0.071370
# BRA Mean                0.608208  0.753682  0.061804
# CAN Mean                0.252489  0.274816  0.025653
# CHN Mean                0.795722  1.030792  0.029774
# GBR Mean                0.167354  0.188705  0.019057
# IND Mean                0.936837  1.125207  0.067893
# JPN Mean                0.267772  0.304826  0.013252
# SGP Mean                2.448069  2.606999  0.120876
# USA Mean                0.446287  0.454971  0.039855
# AUS Median              0.403926  0.414115  0.071370
# BRA Median              0.608208  0.753682  0.061804
# CAN Median              0.252489  0.274816  0.025653
# CHN Median              0.795722  1.030792  0.029774
# GBR Median              0.167354  0.188705  0.019057
# IND Median              0.936837  1.125207  0.067893
# JPN Median              0.267772  0.304826  0.013252
# SGP Median              2.448069  2.606999  0.120876
# USA Median              0.446287  0.454971  0.039855
# AUS LOCF                0.403926  0.414115  0.071370
# BRA LOCF                0.608208  0.753682  0.061804
# CAN LOCF                0.252489  0.274816  0.025653
# CHN LOCF                0.795722  1.030792  0.029774
# GBR LOCF                0.167354  0.188705  0.019057
# IND LOCF                0.936837  1.125207  0.067893
# JPN LOCF                0.267772  0.304826  0.013252
# SGP LOCF                2.448069  2.606999  0.120876
# USA LOCF                0.446287  0.454971  0.039855
# AUS NOCB                0.403926  0.414115  0.071370
# BRA NOCB                0.608208  0.753682  0.061804
# CAN NOCB                0.252489  0.274816  0.025653
# CHN NOCB                0.795722  1.030792  0.029774
# GBR NOCB                0.167354  0.188705  0.019057
# IND NOCB                0.936837  1.125207  0.067893
# JPN NOCB                0.267772  0.304826  0.013252
# SGP NOCB                2.448069  2.606999  0.120876
# USA NOCB                0.446287  0.454971  0.039855
# AUS Rolling statistics  0.759326  0.819110  0.112169
# BRA Rolling statistics  0.632983  0.710374  0.056669
# CAN Rolling statistics  0.616668  0.650601  0.058159
# CHN Rolling statistics  1.243506  1.374093  0.042984
# GBR Rolling statistics  0.362590  0.393802  0.038753
# IND Rolling statistics  0.566446  0.655406  0.037567
# JPN Rolling statistics  0.034087  0.047660  0.001679
# SGP Rolling statistics  0.115929  0.127825  0.005850
# USA Rolling statistics  0.376224  0.404243  0.032030

# %%
s_eval = pd.DataFrame(s_metrics).transpose()
s_eval.columns = ['MAE','RMSE','MAPE']
s_eval
# Out:
#                              MAE      RMSE      MAPE
# AUS Mean                1.828189  1.883519  0.027603
# BRA Mean                1.010412  1.738804  0.016789
# CAN Mean                1.716064  1.904473  0.025519
# CHN Mean                1.236163  1.404015  0.022913
# GBR Mean                0.565637  0.804392  0.007844
# IND Mean                0.773075  1.140966  0.015645
# JPN Mean                0.284643  0.303346  0.004097
# SGP Mean                0.764876  0.884622  0.010894
# USA Mean                0.968015  1.568313  0.012213
# AUS Median              1.828189  1.883519  0.027603
# BRA Median              1.010412  1.738804  0.016789
# CAN Median              1.716064  1.904473  0.025519
# CHN Median              1.236163  1.404015  0.022913
# GBR Median              0.565637  0.804392  0.007844
# IND Median              0.773075  1.140966  0.015645
# JPN Median              0.284643  0.303346  0.004097
# SGP Median              0.764876  0.884622  0.010894
# USA Median              0.968015  1.568313  0.012213
# AUS LOCF                1.828189  1.883519  0.027603
# BRA LOCF                1.010412  1.738804  0.016789
# CAN LOCF                1.716064  1.904473  0.025519
# CHN LOCF                1.236163  1.404015  0.022913
# GBR LOCF                0.565637  0.804392  0.007844
# IND LOCF                0.773075  1.140966  0.015645
# JPN LOCF                0.284643  0.303346  0.004097
# SGP LOCF                0.764876  0.884622  0.010894
# USA LOCF                0.968015  1.568313  0.012213
# AUS NOCB                1.828189  1.883519  0.027603
# BRA NOCB                1.010412  1.738804  0.016789
# CAN NOCB                1.716064  1.904473  0.025519
# CHN NOCB                1.236163  1.404015  0.022913
# GBR NOCB                0.565637  0.804392  0.007844
# IND NOCB                0.773075  1.140966  0.015645
# JPN NOCB                0.284643  0.303346  0.004097
# SGP NOCB                0.764876  0.884622  0.010894
# USA NOCB                0.968015  1.568313  0.012213
# AUS Rolling statistics  0.292241  0.296366  0.004424
# BRA Rolling statistics  1.122672  1.174802  0.018395
# CAN Rolling statistics  0.888409  1.028976  0.013555
# CHN Rolling statistics  2.794216  3.034643  0.056386
# GBR Rolling statistics  0.456438  0.534810  0.006460
# IND Rolling statistics  0.947672  1.047287  0.020075
# JPN Rolling statistics  0.270420  0.303629  0.003866
# SGP Rolling statistics  0.697963  0.771020  0.010063
# USA Rolling statistics  0.706637  0.795885  0.009240

# %% [markdown]
# #### MCMC - Full Bayesian Sampling¶

# %%
response_col = 'Manufacturing_value added_%_of_GDP'
date_col = 'Year'
for con in country:
  for m in method:
    fitting_ETS(m, con, response_col, date_col, forecast_manu, train_manu, valid_manu,5, 'stan-mcmc')

response_col = 'Services_value_added_%_of_GDP'
date_col = 'Year'
for con in country:
  for m in method:
    fitting_ETS(m, con, response_col, date_col, forecast_ser,train_ser, valid_ser,5 ,'stan-mcmc')
# Out:
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed

# %%
m_metrics = {}
s_metrics = {}
for m in method:
  for con in country:
    if len(train_manu[(con,m)].columns) > 1 and 'Manufacturing_value added_%_of_GDP' in valid_manu[(con,m)].columns:
      y = valid_manu[(con,m)]['Manufacturing_value added_%_of_GDP']
      yhat = forecast_manu[(con,m)]['prediction']
      mae = mean_absolute_error(y, yhat)
      mape = mean_absolute_percentage_error(y, yhat)
      rmse = sqrt(mean_squared_error(y, yhat))
      eval =  [mae,rmse,mape]
    #print(mae, mse, rmse, con)
      m_metrics[(con,m)] = eval
    elif len(train_manu[(con,m)].columns) == 1:
      print(f'Only contains target variable for service {con} {m}.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]
    else:
      print(f'Target variable for manufaturce {con} {m} is non-stationary.')
      m_metrics[(con,m)] = [np.nan,np.nan,np.nan]

    if  len(train_ser[(con,m)].columns) > 1 and 'Services_value_added_%_of_GDP' in valid_ser[(con,m)].columns:
      y = valid_ser[(con,m)]['Services_value_added_%_of_GDP']
      yhat = forecast_ser[(con,m)]['prediction']
      mae = mean_absolute_error(y, yhat)
      mape = mean_absolute_percentage_error(y, yhat)
      rmse = sqrt(mean_squared_error(y, yhat))
      eval = [mae,rmse,mape]
      #print(mae, mse, rmse, con)
      s_metrics[(con,m)] = eval
    elif len(train_ser[(con,m)].columns) == 1:
      print(f'Only contains target variable for service {con} {m}.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]
    else:
      print(f'Target variable for service {con} {m} is non-stationary.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]

# %%
m_eval = pd.DataFrame(m_metrics).transpose()
m_eval.columns = ['MAE', 'RMSE','MAPE']

m_eval
# Out:
#                              MAE      RMSE      MAPE
# AUS Mean                0.435871  0.455018  0.077077
# BRA Mean                0.799052  0.912611  0.080467
# CAN Mean                0.187334  0.235803  0.018992
# CHN Mean                1.027950  1.231088  0.038306
# GBR Mean                0.211469  0.226436  0.024021
# IND Mean                1.057400  1.225233  0.076371
# JPN Mean                0.303911  0.324366  0.014958
# SGP Mean                2.271355  2.431776  0.112069
# USA Mean                0.476224  0.496754  0.042553
# AUS Median              0.435871  0.455018  0.077077
# BRA Median              0.799052  0.912611  0.080467
# CAN Median              0.187334  0.235803  0.018992
# CHN Median              1.027950  1.231088  0.038306
# GBR Median              0.211469  0.226436  0.024021
# IND Median              1.057400  1.225233  0.076371
# JPN Median              0.303911  0.324366  0.014958
# SGP Median              2.271355  2.431776  0.112069
# USA Median              0.476224  0.496754  0.042553
# AUS LOCF                0.435871  0.455018  0.077077
# BRA LOCF                0.799052  0.912611  0.080467
# CAN LOCF                0.187334  0.235803  0.018992
# CHN LOCF                1.027950  1.231088  0.038306
# GBR LOCF                0.211469  0.226436  0.024021
# IND LOCF                1.057400  1.225233  0.076371
# JPN LOCF                0.303911  0.324366  0.014958
# SGP LOCF                2.271355  2.431776  0.112069
# USA LOCF                0.476224  0.496754  0.042553
# AUS NOCB                0.435871  0.455018  0.077077
# BRA NOCB                0.799052  0.912611  0.080467
# CAN NOCB                0.187334  0.235803  0.018992
# CHN NOCB                1.027950  1.231088  0.038306
# GBR NOCB                0.211469  0.226436  0.024021
# IND NOCB                1.057400  1.225233  0.076371
# JPN NOCB                0.303911  0.324366  0.014958
# SGP NOCB                2.271355  2.431776  0.112069
# USA NOCB                0.476224  0.496754  0.042553
# AUS Rolling statistics  0.794474  0.856581  0.117338
# BRA Rolling statistics  0.715368  0.786870  0.063934
# CAN Rolling statistics  0.642943  0.691348  0.060700
# CHN Rolling statistics  1.344611  1.463989  0.046442
# GBR Rolling statistics  0.390040  0.424323  0.041682
# IND Rolling statistics  0.586401  0.674136  0.038879
# JPN Rolling statistics  0.050746  0.060150  0.002499
# SGP Rolling statistics  0.126744  0.152826  0.006408
# USA Rolling statistics  0.398163  0.435676  0.033917

# %%
s_eval = pd.DataFrame(s_metrics).transpose()
s_eval.columns = ['MAE','RMSE','MAPE']
s_eval
# Out:
#                              MAE      RMSE      MAPE
# AUS Mean                1.684221  1.754009  0.025437
# BRA Mean                1.176198  1.868013  0.019467
# CAN Mean                1.748684  1.985079  0.025984
# CHN Mean                1.233062  1.441011  0.022837
# GBR Mean                0.601811  0.846980  0.008351
# IND Mean                0.798373  1.127706  0.016186
# JPN Mean                0.403019  0.442020  0.005801
# SGP Mean                0.763684  0.910472  0.010909
# USA Mean                1.006878  1.544071  0.012727
# AUS Median              1.684221  1.754009  0.025437
# BRA Median              1.176198  1.868013  0.019467
# CAN Median              1.748684  1.985079  0.025984
# CHN Median              1.233062  1.441011  0.022837
# GBR Median              0.601811  0.846980  0.008351
# IND Median              0.798373  1.127706  0.016186
# JPN Median              0.403019  0.442020  0.005801
# SGP Median              0.763684  0.910472  0.010909
# USA Median              1.006878  1.544071  0.012727
# AUS LOCF                1.684221  1.754009  0.025437
# BRA LOCF                1.176198  1.868013  0.019467
# CAN LOCF                1.748684  1.985079  0.025984
# CHN LOCF                1.233062  1.441011  0.022837
# GBR LOCF                0.601811  0.846980  0.008351
# IND LOCF                0.798373  1.127706  0.016186
# JPN LOCF                0.403019  0.442020  0.005801
# SGP LOCF                0.763684  0.910472  0.010909
# USA LOCF                1.006878  1.544071  0.012727
# AUS NOCB                1.684221  1.754009  0.025437
# BRA NOCB                1.176198  1.868013  0.019467
# CAN NOCB                1.748684  1.985079  0.025984
# CHN NOCB                1.233062  1.441011  0.022837
# GBR NOCB                0.601811  0.846980  0.008351
# IND NOCB                0.798373  1.127706  0.016186
# JPN NOCB                0.403019  0.442020  0.005801
# SGP NOCB                0.763684  0.910472  0.010909
# USA NOCB                1.006878  1.544071  0.012727
# AUS Rolling statistics  0.293290  0.302665  0.004440
# BRA Rolling statistics  1.065064  1.136054  0.017446
# CAN Rolling statistics  0.921972  1.048924  0.014072
# CHN Rolling statistics  2.772709  3.023053  0.055938
# GBR Rolling statistics  0.443882  0.522741  0.006282
# IND Rolling statistics  0.928563  1.033809  0.019667
# JPN Rolling statistics  0.239915  0.307694  0.003432
# SGP Rolling statistics  0.680924  0.759306  0.009816
# USA Rolling statistics  0.700343  0.775238  0.009159

# %% [markdown]
# ### Damped Local Trend (DLT)

# %% [markdown]
# #### Linear trends

# %%
forecast_manu = {}
forecast_ser = {}
def fitting_DLT(m, con, response_col, date_col, result, train, test, seasonality = 5,estimator = 'stan-map',global_trend_option = 'linear'):
  dlt = DLT(
    response_col=response_col,
    date_col=date_col,
    estimator='stan-map',
    seed=8888,
    global_trend_option= global_trend_option,
    # for prediction uncertainty
    n_bootstrap_draws=1000,
)
  dlt.fit(df=train[(con,m)])
  predicted_df = dlt.predict(df=test[(con,m)])
  result[(con,m)] = predicted_df

# %%
response_col = 'Manufacturing_value added_%_of_GDP'
date_col = 'Year'
for con in country:
  for m in method:
    fitting_DLT(m, con, response_col, date_col, forecast_manu, train_manu, valid_manu)

response_col = 'Services_value_added_%_of_GDP'
date_col = 'Year'
for con in country:
  for m in method:
    fitting_DLT(m, con, response_col, date_col, forecast_ser,train_ser, valid_ser)

# %%
m_metrics = {}
s_metrics = {}
for m in method:
  for con in country:
    if len(train_manu[(con,m)].columns) > 1 and 'Manufacturing_value added_%_of_GDP' in valid_manu[(con,m)].columns:
      y = valid_manu[(con,m)]['Manufacturing_value added_%_of_GDP']
      yhat = forecast_manu[(con,m)]['prediction']
      mae = mean_absolute_error(y, yhat)
      mape = mean_absolute_percentage_error(y, yhat)
      rmse = sqrt(mean_squared_error(y, yhat))
      eval =  [mae,rmse,mape]
    #print(mae, mse, rmse, con)
      m_metrics[(con,m)] = eval
    elif len(train_manu[(con,m)].columns) == 1:
      print(f'Only contains target variable for service {con} {m}.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]
    else:
      print(f'Target variable for manufaturce {con} {m} is non-stationary.')
      m_metrics[(con,m)] = [np.nan,np.nan,np.nan]

    if  len(train_ser[(con,m)].columns) > 1 and 'Services_value_added_%_of_GDP' in valid_ser[(con,m)].columns:
      y = valid_ser[(con,m)]['Services_value_added_%_of_GDP']
      yhat = forecast_ser[(con,m)]['prediction']
      mae = mean_absolute_error(y, yhat)
      mape = mean_absolute_percentage_error(y, yhat)
      rmse = sqrt(mean_squared_error(y, yhat))
      eval = [mae,rmse,mape]
      #print(mae, mse, rmse, con)
      s_metrics[(con,m)] = eval
    elif len(train_ser[(con,m)].columns) == 1:
      print(f'Only contains target variable for service {con} {m}.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]
    else:
      print(f'Target variable for service {con} {m} is non-stationary.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]

# %%
m_eval = pd.DataFrame(m_metrics).transpose()
m_eval.columns = ['MAE', 'RMSE','MAPE']

m_eval
# Out:
#                              MAE      RMSE      MAPE
# AUS Mean                0.484157  0.589798  0.086064
# BRA Mean                0.215617  0.237081  0.020968
# CAN Mean                0.860738  0.959935  0.087372
# CHN Mean                0.981321  1.142583  0.035782
# GBR Mean                0.560993  0.646505  0.063815
# IND Mean                0.765286  0.953864  0.055641
# JPN Mean                0.651426  0.688812  0.032074
# SGP Mean                3.271280  3.480848  0.161617
# USA Mean                0.166076  0.199986  0.014789
# AUS Median              0.484157  0.589798  0.086064
# BRA Median              0.215617  0.237081  0.020968
# CAN Median              0.860738  0.959935  0.087372
# CHN Median              0.981321  1.142583  0.035782
# GBR Median              0.560993  0.646505  0.063815
# IND Median              0.765286  0.953864  0.055641
# JPN Median              0.651426  0.688812  0.032074
# SGP Median              3.271280  3.480848  0.161617
# USA Median              0.166076  0.199986  0.014789
# AUS LOCF                0.484157  0.589798  0.086064
# BRA LOCF                0.215617  0.237081  0.020968
# CAN LOCF                0.860738  0.959935  0.087372
# CHN LOCF                0.981321  1.142583  0.035782
# GBR LOCF                0.560993  0.646505  0.063815
# IND LOCF                0.765286  0.953864  0.055641
# JPN LOCF                0.651426  0.688812  0.032074
# SGP LOCF                3.271280  3.480848  0.161617
# USA LOCF                0.166076  0.199986  0.014789
# AUS NOCB                0.484157  0.589798  0.086064
# BRA NOCB                0.215617  0.237081  0.020968
# CAN NOCB                0.860738  0.959935  0.087372
# CHN NOCB                0.981321  1.142583  0.035782
# GBR NOCB                0.560993  0.646505  0.063815
# IND NOCB                0.765286  0.953864  0.055641
# JPN NOCB                0.651426  0.688812  0.032074
# SGP NOCB                3.271280  3.480848  0.161617
# USA NOCB                0.166076  0.199986  0.014789
# AUS Rolling statistics  0.212162  0.269408  0.031831
# BRA Rolling statistics  0.054701  0.082282  0.004968
# CAN Rolling statistics  0.140114  0.165420  0.013287
# CHN Rolling statistics  0.227511  0.299751  0.007921
# GBR Rolling statistics  0.200660  0.240722  0.021525
# IND Rolling statistics  0.304320  0.381359  0.020257
# JPN Rolling statistics  0.095568  0.103502  0.004700
# SGP Rolling statistics  1.084852  1.237129  0.054531
# USA Rolling statistics  0.034052  0.040931  0.002884

# %%
s_eval = pd.DataFrame(s_metrics).transpose()
s_eval.columns = ['MAE','RMSE','MAPE']
s_eval
# Out:
#                              MAE      RMSE      MAPE
# AUS Mean                3.098628  3.290944  0.046817
# BRA Mean                3.629694  4.421576  0.059269
# CAN Mean                1.497154  1.651440  0.022274
# CHN Mean                2.201681  2.552600  0.041047
# GBR Mean                0.755836  0.794859  0.010605
# IND Mean                0.920976  1.128289  0.019009
# JPN Mean                0.813734  0.896699  0.011711
# SGP Mean                1.307784  1.586028  0.018747
# USA Mean                0.811014  1.085727  0.010303
# AUS Median              3.098628  3.290944  0.046817
# BRA Median              3.629694  4.421576  0.059269
# CAN Median              1.497154  1.651440  0.022274
# CHN Median              2.201681  2.552600  0.041047
# GBR Median              0.755836  0.794859  0.010605
# IND Median              0.920976  1.128289  0.019009
# JPN Median              0.813734  0.896699  0.011711
# SGP Median              1.307784  1.586028  0.018747
# USA Median              0.811014  1.085727  0.010303
# AUS LOCF                3.098628  3.290944  0.046817
# BRA LOCF                3.629694  4.421576  0.059269
# CAN LOCF                1.497154  1.651440  0.022274
# CHN LOCF                2.201681  2.552600  0.041047
# GBR LOCF                0.755836  0.794859  0.010605
# IND LOCF                0.920976  1.128289  0.019009
# JPN LOCF                0.813734  0.896699  0.011711
# SGP LOCF                1.307784  1.586028  0.018747
# USA LOCF                0.811014  1.085727  0.010303
# AUS NOCB                3.098628  3.290944  0.046817
# BRA NOCB                3.629694  4.421576  0.059269
# CAN NOCB                1.497154  1.651440  0.022274
# CHN NOCB                2.201681  2.552600  0.041047
# GBR NOCB                0.755836  0.794859  0.010605
# IND NOCB                0.920976  1.128289  0.019009
# JPN NOCB                0.813734  0.896699  0.011711
# SGP NOCB                1.307784  1.586028  0.018747
# USA NOCB                0.811014  1.085727  0.010303
# AUS Rolling statistics  0.665872  0.767532  0.010079
# BRA Rolling statistics  0.739721  0.958712  0.012107
# CAN Rolling statistics  0.474476  0.554885  0.007239
# CHN Rolling statistics  0.076793  0.113031  0.001549
# GBR Rolling statistics  0.133019  0.149080  0.001887
# IND Rolling statistics  0.111597  0.128401  0.002366
# JPN Rolling statistics  0.348758  0.423588  0.004988
# SGP Rolling statistics  0.324874  0.366671  0.004687
# USA Rolling statistics  0.113289  0.131794  0.001483

# %% [markdown]
# ### Local Global Trend (LGT)

# %%
from orbit.models import LGT

# %%
forecast_manu = {}
forecast_ser = {}
def fitting_LGT(m, con, response_col, date_col, result, train, test, seasonality = 5,estimator = 'stan-map'):
  lgt = LGT(
    response_col=response_col,
    date_col=date_col,
    estimator='stan-map',
    seed=8888,
)
  lgt.fit(df=train[(con,m)])
  predicted_df = lgt.predict(df=test[(con,m)])
  result[(con,m)] = predicted_df

# %%
response_col = 'Manufacturing_value added_%_of_GDP'
date_col = 'Year'
for con in country:
  for m in method:
    fitting_DLT(m, con, response_col, date_col, forecast_manu, train_manu, valid_manu)

response_col = 'Services_value_added_%_of_GDP'
date_col = 'Year'
for con in country:
  for m in method:
    fitting_DLT(m, con, response_col, date_col, forecast_ser,train_ser, valid_ser)

# %%
m_metrics = {}
s_metrics = {}
for m in method:
  for con in country:
    if len(train_manu[(con,m)].columns) > 1 and 'Manufacturing_value added_%_of_GDP' in valid_manu[(con,m)].columns:
      y = valid_manu[(con,m)]['Manufacturing_value added_%_of_GDP']
      yhat = forecast_manu[(con,m)]['prediction']
      mae = mean_absolute_error(y, yhat)
      mape = mean_absolute_percentage_error(y, yhat)
      rmse = sqrt(mean_squared_error(y, yhat))
      eval =  [mae,rmse,mape]
    #print(mae, mse, rmse, con)
      m_metrics[(con,m)] = eval
    elif len(train_manu[(con,m)].columns) == 1:
      print(f'Only contains target variable for service {con} {m}.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]
    else:
      print(f'Target variable for manufaturce {con} {m} is non-stationary.')
      m_metrics[(con,m)] = [np.nan,np.nan,np.nan]

    if  len(train_ser[(con,m)].columns) > 1 and 'Services_value_added_%_of_GDP' in valid_ser[(con,m)].columns:
      y = valid_ser[(con,m)]['Services_value_added_%_of_GDP']
      yhat = forecast_ser[(con,m)]['prediction']
      mae = mean_absolute_error(y, yhat)
      mape = mean_absolute_percentage_error(y, yhat)
      rmse = sqrt(mean_squared_error(y, yhat))
      eval = [mae,rmse,mape]
      #print(mae, mse, rmse, con)
      s_metrics[(con,m)] = eval
    elif len(train_ser[(con,m)].columns) == 1:
      print(f'Only contains target variable for service {con} {m}.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]
    else:
      print(f'Target variable for service {con} {m} is non-stationary.')
      s_metrics[(con,m)] = [np.nan,np.nan,np.nan]

# %%
m_eval = pd.DataFrame(m_metrics).transpose()
m_eval.columns = ['MAE', 'RMSE','MAPE']

m_eval
# Out:
#                              MAE      RMSE      MAPE
# AUS Mean                0.484157  0.589798  0.086064
# BRA Mean                0.215617  0.237081  0.020968
# CAN Mean                0.860738  0.959935  0.087372
# CHN Mean                0.981321  1.142583  0.035782
# GBR Mean                0.560993  0.646505  0.063815
# IND Mean                0.765286  0.953864  0.055641
# JPN Mean                0.651426  0.688812  0.032074
# SGP Mean                3.271280  3.480848  0.161617
# USA Mean                0.166076  0.199986  0.014789
# AUS Median              0.484157  0.589798  0.086064
# BRA Median              0.215617  0.237081  0.020968
# CAN Median              0.860738  0.959935  0.087372
# CHN Median              0.981321  1.142583  0.035782
# GBR Median              0.560993  0.646505  0.063815
# IND Median              0.765286  0.953864  0.055641
# JPN Median              0.651426  0.688812  0.032074
# SGP Median              3.271280  3.480848  0.161617
# USA Median              0.166076  0.199986  0.014789
# AUS LOCF                0.484157  0.589798  0.086064
# BRA LOCF                0.215617  0.237081  0.020968
# CAN LOCF                0.860738  0.959935  0.087372
# CHN LOCF                0.981321  1.142583  0.035782
# GBR LOCF                0.560993  0.646505  0.063815
# IND LOCF                0.765286  0.953864  0.055641
# JPN LOCF                0.651426  0.688812  0.032074
# SGP LOCF                3.271280  3.480848  0.161617
# USA LOCF                0.166076  0.199986  0.014789
# AUS NOCB                0.484157  0.589798  0.086064
# BRA NOCB                0.215617  0.237081  0.020968
# CAN NOCB                0.860738  0.959935  0.087372
# CHN NOCB                0.981321  1.142583  0.035782
# GBR NOCB                0.560993  0.646505  0.063815
# IND NOCB                0.765286  0.953864  0.055641
# JPN NOCB                0.651426  0.688812  0.032074
# SGP NOCB                3.271280  3.480848  0.161617
# USA NOCB                0.166076  0.199986  0.014789
# AUS Rolling statistics  0.212162  0.269408  0.031831
# BRA Rolling statistics  0.054701  0.082282  0.004968
# CAN Rolling statistics  0.140114  0.165420  0.013287
# CHN Rolling statistics  0.227511  0.299751  0.007921
# GBR Rolling statistics  0.200660  0.240722  0.021525
# IND Rolling statistics  0.304320  0.381359  0.020257
# JPN Rolling statistics  0.095568  0.103502  0.004700
# SGP Rolling statistics  1.084852  1.237129  0.054531
# USA Rolling statistics  0.034052  0.040931  0.002884

# %%
s_eval = pd.DataFrame(s_metrics).transpose()
s_eval.columns = ['MAE','RMSE','MAPE']
s_eval
# Out:
#                              MAE      RMSE      MAPE
# AUS Mean                3.098628  3.290944  0.046817
# BRA Mean                3.629694  4.421576  0.059269
# CAN Mean                1.497154  1.651440  0.022274
# CHN Mean                2.201681  2.552600  0.041047
# GBR Mean                0.755836  0.794859  0.010605
# IND Mean                0.920976  1.128289  0.019009
# JPN Mean                0.813734  0.896699  0.011711
# SGP Mean                1.307784  1.586028  0.018747
# USA Mean                0.811014  1.085727  0.010303
# AUS Median              3.098628  3.290944  0.046817
# BRA Median              3.629694  4.421576  0.059269
# CAN Median              1.497154  1.651440  0.022274
# CHN Median              2.201681  2.552600  0.041047
# GBR Median              0.755836  0.794859  0.010605
# IND Median              0.920976  1.128289  0.019009
# JPN Median              0.813734  0.896699  0.011711
# SGP Median              1.307784  1.586028  0.018747
# USA Median              0.811014  1.085727  0.010303
# AUS LOCF                3.098628  3.290944  0.046817
# BRA LOCF                3.629694  4.421576  0.059269
# CAN LOCF                1.497154  1.651440  0.022274
# CHN LOCF                2.201681  2.552600  0.041047
# GBR LOCF                0.755836  0.794859  0.010605
# IND LOCF                0.920976  1.128289  0.019009
# JPN LOCF                0.813734  0.896699  0.011711
# SGP LOCF                1.307784  1.586028  0.018747
# USA LOCF                0.811014  1.085727  0.010303
# AUS NOCB                3.098628  3.290944  0.046817
# BRA NOCB                3.629694  4.421576  0.059269
# CAN NOCB                1.497154  1.651440  0.022274
# CHN NOCB                2.201681  2.552600  0.041047
# GBR NOCB                0.755836  0.794859  0.010605
# IND NOCB                0.920976  1.128289  0.019009
# JPN NOCB                0.813734  0.896699  0.011711
# SGP NOCB                1.307784  1.586028  0.018747
# USA NOCB                0.811014  1.085727  0.010303
# AUS Rolling statistics  0.665872  0.767532  0.010079
# BRA Rolling statistics  0.739721  0.958712  0.012107
# CAN Rolling statistics  0.474476  0.554885  0.007239
# CHN Rolling statistics  0.076793  0.113031  0.001549
# GBR Rolling statistics  0.133019  0.149080  0.001887
# IND Rolling statistics  0.111597  0.128401  0.002366
# JPN Rolling statistics  0.348758  0.423588  0.004988
# SGP Rolling statistics  0.324874  0.366671  0.004687
# USA Rolling statistics  0.113289  0.131794  0.001483
