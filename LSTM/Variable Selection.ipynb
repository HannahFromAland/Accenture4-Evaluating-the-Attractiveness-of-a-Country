# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd /content/drive/MyDrive/Capstone_Accenture4/Meet2/Missing data
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Capstone_Accenture4/Meet2/Missing data

# %% [markdown]
# #### Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from time import time

import tensorflow as tf
import tensorflow.keras.backend as K

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras import layers
from tensorflow.keras.callbacks import History, EarlyStopping
from tensorflow import keras

# %% [markdown]
# ### Global

# %%
dic_country = \
{'AUS': 'Australia',
 'BRA': 'Brazil',
 'CAN': 'India',
 'CHN': 'China',
 'GBR': 'United Kingdom',
 'IND': 'India',
 'JPN': 'Japan',
 'SGP': 'Singapore',
 'USA': 'United States'}
pd.DataFrame(dic_country,index=[0]).T.reset_index().rename(columns = {'index': 'country_code', 0: 'country_name'})
# Out:
#   country_code    country_name
# 0          AUS       Australia
# 1          BRA          Brazil
# 2          CAN           India
# 3          CHN           China
# 4          GBR  United Kingdom
# 5          IND           India
# 6          JPN           Japan
# 7          SGP       Singapore
# 8          USA   United States

# %% [markdown]
# ### Data
#
# Use (country_code, imputation_method) to store corresponding df
# - m_dfs: manufacturing data
# - s_dfs: service data

# %%
# %cd /content/drive/MyDrive/Capstone_Accenture4/LSTM/Data/
Data_dic_m = pd.ExcelFile('Manufacturing.1.xlsx')
Data_dic_s = pd.ExcelFile('Service.1.xlsx')
# Out:
# /content/drive/MyDrive/Capstone_Accenture4/LSTM/Data

# %%
m_dfs = {}
for i in range(len(Data_dic_m.sheet_names)):
    sheet = Data_dic_m.sheet_names[i]
    df = pd.read_excel(Data_dic_m, sheet_name=sheet)
    df['Year'] = [i.year for i in pd.to_datetime(df.Year, format='%Y')]
    df = df.set_index('Year')
    m_dfs[sheet[:3]] = df

# %%
s_dfs = {}
for i in range(len(Data_dic_s.sheet_names)):
    sheet = Data_dic_s.sheet_names[i]
    df = pd.read_excel(Data_dic_s, sheet_name=sheet)
    df['Year'] = [i.year for i in pd.to_datetime(df.Year, format='%Y')]
    df = df.set_index('Year')
    s_dfs[sheet[:3]] = df

# %%
def clean_nan(data, target = 'Manufacturing_value added_%_of_GDP'):
  data = data.replace('..', np.nan)
  # drop all column 0
  data = data.dropna(axis=1, how='all')
  # drop nan row according to target
  data = data[data[target].notna()]
  return data.fillna(data.median())

# %% [markdown]
# #### pairwise scatterplot

# %% [markdown]
# ##### Manufacturing

# %%
def make_pairwise_plot(country = 'CHN', df = None, name = 'Manufacture_GDP%', num = 4):
  data = df[country].replace('..', np.nan)
  subdata = data.dropna(axis=1, how='all')
  g = sns.FacetGrid(pd.DataFrame(list(subdata.columns[:-1])), col=0, col_wrap=num, sharex=False, height=2.6, aspect=1.7)
  for ax, x_var in zip(g.axes, list(subdata.columns[:-1])):
      subdata = subdata.rename(columns={subdata.columns[-1]: name})
      y = [subdata.columns[-1]]
      x = [x_var]
      sns.scatterplot(data = subdata[x+y].dropna(), x=x[0], y=y[0], ax=ax, hue=y[0], palette="coolwarm", legend=False)
  g.tight_layout()
  g.fig.subplots_adjust(top=0.92)
  g.fig.suptitle(dic_country[country] + ' : ' + name + ' v.s. other variables',fontsize=16, weight='bold')
  return g

# %%
make_pairwise_plot('CHN',df=m_dfs)

# %%
for country in m_dfs.keys():
  make_pairwise_plot(country,df=m_dfs, num=4)

# %% [markdown]
# ##### Service

# %%
make_pairwise_plot(country = 'CHN',df = s_dfs, name = 'Service_GDP%', num=4)

# %%
for country in s_dfs.keys():
  make_pairwise_plot(country = country,df = s_dfs, name = 'Service_GDP%', num=5)

# %% [markdown]
# #### Correlation plot

# %%
df = m_dfs['CHN']
df = df.drop('Access_finance', axis =1)
corr = df.replace('..', np.nan).corr()
corr[['Manufacturing_value added_%_of_GDP']].style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_347c5_row0_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_347c5_row1_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_347c5_row2_col0, #T_347c5_row11_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_347c5_row3_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_347c5_row4_col0 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_347c5_row5_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_347c5_row6_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_347c5_row7_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_347c5_row8_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_347c5_row9_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_347c5_row10_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_347c5_row12_col0, #T_347c5_row14_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_347c5_row13_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_347c5_row15_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_347c5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Manufacturing_value added_%_of_GDP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_347c5_level0_row0" class="row_heading level0 row0" >Employment_in_industry_male</th>
#       <td id="T_347c5_row0_col0" class="data row0 col0" >-0.541068</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row1" class="row_heading level0 row1" >High_technology_exports</th>
#       <td id="T_347c5_row1_col0" class="data row1 col0" >-0.149990</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row2" class="row_heading level0 row2" >Research_development_expenditure</th>
#       <td id="T_347c5_row2_col0" class="data row2 col0" >-0.878800</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row3" class="row_heading level0 row3" >Researchers in R&D</th>
#       <td id="T_347c5_row3_col0" class="data row3 col0" >-0.864297</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row4" class="row_heading level0 row4" >Population_labor_rate</th>
#       <td id="T_347c5_row4_col0" class="data row4 col0" >0.790016</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row5" class="row_heading level0 row5" >Population_density</th>
#       <td id="T_347c5_row5_col0" class="data row5 col0" >-0.931529</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row6" class="row_heading level0 row6" >Foreign_direct_investment</th>
#       <td id="T_347c5_row6_col0" class="data row6 col0" >0.901789</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row7" class="row_heading level0 row7" >Net_trade_in_goods_services</th>
#       <td id="T_347c5_row7_col0" class="data row7 col0" >-0.242741</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row8" class="row_heading level0 row8" >Air_freight_million_ton_km</th>
#       <td id="T_347c5_row8_col0" class="data row8 col0" >-0.842567</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row9" class="row_heading level0 row9" >Container_port_traffic_TEU</th>
#       <td id="T_347c5_row9_col0" class="data row9 col0" >-0.918694</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row10" class="row_heading level0 row10" >Railways_goods_trans_million_ton-km</th>
#       <td id="T_347c5_row10_col0" class="data row10 col0" >-0.264728</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row11" class="row_heading level0 row11" >Industry_value_added_current_USD</th>
#       <td id="T_347c5_row11_col0" class="data row11 col0" >-0.873641</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row12" class="row_heading level0 row12" >GDP_per_capita_current_USD</th>
#       <td id="T_347c5_row12_col0" class="data row12 col0" >-0.910827</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row13" class="row_heading level0 row13" >Final_consumption</th>
#       <td id="T_347c5_row13_col0" class="data row13 col0" >-0.939466</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row14" class="row_heading level0 row14" >New_business_density</th>
#       <td id="T_347c5_row14_col0" class="data row14 col0" >-0.912354</td>
#     </tr>
#     <tr>
#       <th id="T_347c5_level0_row15" class="row_heading level0 row15" >Manufacturing_value added_%_of_GDP</th>
#       <td id="T_347c5_row15_col0" class="data row15 col0" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr[target]
# Out:
# Employment_in_industry_male           -0.541068
# High_technology_exports               -0.149990
# Research_development_expenditure      -0.878800
# Researchers in R&D                    -0.864297
# Population_labor_rate                  0.790016
# Population_density                    -0.931529
# Foreign_direct_investment              0.901789
# Net_trade_in_goods_services           -0.242741
# Air_freight_million_ton_km            -0.842567
# Container_port_traffic_TEU            -0.918694
# Railways_goods_trans_million_ton-km   -0.264728
# Industry_value_added_current_USD      -0.873641
# GDP_per_capita_current_USD            -0.910827
# Final_consumption                     -0.939466
# New_business_density                  -0.912354
# Name: Manufacturing_value added_%_of_GDP, dtype: float64

# %%
for i in np.arange(argmin, argmax, step):
  print(i)
# Out:
# -0.9394660959334549
# -0.7553406193811948
# -0.5712151428289347
# -0.3870896662766746
# -0.20296418972441455
# -0.018838713172154464
# 0.16528676338010562
# 0.3494122399323656
# 0.5335377164846258
# 0.717663193036886

# %%
 max(corr[[target]].values)[0]
# Out:
# 0.9017886695891458

# %%
import plotly.graph_objects as go

df = m_dfs['CHN']
df = df.drop('Access_finance', axis =1)
corr = df.replace('..', np.nan).corr()
cmap = sns.color_palette('coolwarm', 10).as_hex()[:]

fig = go.Figure(data=[go.Table(
    header=dict(values=['<b>Variables</b>', '<b>Manufacturing_value added_%_of_GDP%_of_GDP</b>'],
                line_color='darkslategray',
                fill_color='white',
                height=29,
                align=['left', 'center']),
    cells=dict(values=round(corr[['Manufacturing_value added_%_of_GDP']],4).reset_index().values[:-1,:].T,
               line_color='darkslategray',
               font=dict(color='black'),
               fill_color=[[cmap[1], cmap[2], cmap[0], cmap[0], cmap[-2], cmap[0], cmap[-1], cmap[2], cmap[0], cmap[0], cmap[2], cmap[0]]],
               height=33,
               align=['left', 'center'])),
])

fig.update_layout(width=700, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2a422aac-31fd-44c3-80e6-45b0ba04d08b" class="plotly-graph-div" style="height:800px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a422aac-31fd-44c3-80e6-45b0ba04d08b")) {                    Plotly.newPlot(                        "2a422aac-31fd-44c3-80e6-45b0ba04d08b",                        [{"cells":{"align":["left","center"],"fill":{"color":[["#9abbff","#c9d7f0","#6788ee","#6788ee","#f7a889","#6788ee","#e26952","#c9d7f0","#6788ee","#6788ee","#c9d7f0","#6788ee"]]},"font":{"color":"black"},"height":33,"line":{"color":"darkslategray"},"values":[["Employment_in_industry_male","High_technology_exports","Research_development_expenditure","Researchers in R&D","Population_labor_rate","Population_density","Foreign_direct_investment","Net_trade_in_goods_services","Air_freight_million_ton_km","Container_port_traffic_TEU","Railways_goods_trans_million_ton-km","Industry_value_added_current_USD","GDP_per_capita_current_USD","Final_consumption","New_business_density"],[-0.5411,-0.15,-0.8788,-0.8643,0.79,-0.9315,0.9018,-0.2427,-0.8426,-0.9187,-0.2647,-0.8736,-0.9108,-0.9395,-0.9124]]},"header":{"align":["left","center"],"fill":{"color":"white"},"height":29,"line":{"color":"darkslategray"},"values":["<b>Variables</b>","<b>Manufacturing_value added_%_of_GDP%_of_GDP</b>"]},"type":"table"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewi ...

# %%
import plotly.graph_objects as go

df = m_dfs['CHN']
target = 'Manufacturing_value added_%_of_GDP'
df = df.drop(['Access_finance'] , axis =1)
corr = df.replace('..', np.nan).corr()
corr = corr.drop([target], axis = 0)

argmin = min(corr[[target]].values)[0]
argmax = max(corr[[target]].values)[0]
step = (argmax-argmin)/10
conditions = [(corr[target]<i) & (corr[target]>=i-step) for i in np.arange(argmin, argmax+step, step)]
conditions.insert(-1, (corr[target]>=argmax))
conditions.insert(0, (corr[target]<=argmin))
cmap = sns.color_palette('coolwarm',14).as_hex()[:]
colors = np.select(conditions, cmap)
colors[6] = cmap[-1]
fig = go.Figure(data=[go.Table(
    header=dict(values=['<b>Variables</b>', '<b>Manufacturing_value added_%_of_GDP%_of_GDP</b>'],
                line_color='darkslategray',
                fill_color='white',
                height=29,
                align=['left', 'center']),
    cells=dict(values=round(corr[['Manufacturing_value added_%_of_GDP']],4).reset_index().values[:-1,:].T,
               line_color='darkslategray',
               font=dict(color='black'),
               fill_color=[colors],
               height=33,
               align=['left', 'center'])),
])

fig.update_layout(width=700, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a64e8b34-9292-4e7d-9550-6885b9d14ba3" class="plotly-graph-div" style="height:800px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a64e8b34-9292-4e7d-9550-6885b9d14ba3")) {                    Plotly.newPlot(                        "a64e8b34-9292-4e7d-9550-6885b9d14ba3",                        [{"cells":{"align":["left","center"],"fill":{"color":[["#aac7fd","#d4dbe6","#7b9ff9","#7b9ff9","#ee8468","#7b9ff9","#cc403a","#c0d4f5","#7b9ff9","#7b9ff9","#c0d4f5","#7b9ff9","#7b9ff9","#4f69d9","#7b9ff9"]]},"font":{"color":"black"},"height":33,"line":{"color":"darkslategray"},"values":[["Employment_in_industry_male","High_technology_exports","Research_development_expenditure","Researchers in R&D","Population_labor_rate","Population_density","Foreign_direct_investment","Net_trade_in_goods_services","Air_freight_million_ton_km","Container_port_traffic_TEU","Railways_goods_trans_million_ton-km","Industry_value_added_current_USD","GDP_per_capita_current_USD","Final_consumption"],[-0.5411,-0.15,-0.8788,-0.8643,0.79,-0.9315,0.9018,-0.2427,-0.8426,-0.9187,-0.2647,-0.8736,-0.9108,-0.9395]]},"header":{"align":["left","center"],"fill":{"color":"white"},"height":29,"line":{"color":"darkslategray"},"values":["<b>Variables</b>","<b>Manufacturing_value added_%_of_GDP%_of_GDP</b>"]},"type":"table"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewid ...

# %%
df = s_dfs['CHN']
df = df.drop(['Access_finance','Primary_completion_rate'], axis =1)
corr = df.replace('..', np.nan).corr()

corr[['Services_value_added_%_of_GDP']].style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_57489_row0_col0 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_57489_row1_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_57489_row2_col0 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_57489_row3_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_57489_row4_col0, #T_57489_row12_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_57489_row5_col0 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_57489_row6_col0 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_57489_row7_col0, #T_57489_row10_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_57489_row8_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_57489_row9_col0 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_57489_row11_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_57489_row13_col0 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_57489_row14_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_57489_row15_col0 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_57489_row16_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_57489_row17_col0 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_57489_row18_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_57489_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Services_value_added_%_of_GDP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57489_level0_row0" class="row_heading level0 row0" >Employment_in_services_male</th>
#       <td id="T_57489_row0_col0" class="data row0 col0" >0.967908</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row1" class="row_heading level0 row1" >Urban_population_growth</th>
#       <td id="T_57489_row1_col0" class="data row1 col0" >-0.154895</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row2" class="row_heading level0 row2" >Net_trade_in_goods_services</th>
#       <td id="T_57489_row2_col0" class="data row2 col0" >0.767295</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row3" class="row_heading level0 row3" >Foreign_direct_investment</th>
#       <td id="T_57489_row3_col0" class="data row3 col0" >0.332673</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row4" class="row_heading level0 row4" >Mobile_cellular_subscriptions</th>
#       <td id="T_57489_row4_col0" class="data row4 col0" >0.861563</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row5" class="row_heading level0 row5" >Secure_Internet_servers</th>
#       <td id="T_57489_row5_col0" class="data row5 col0" >0.743774</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row6" class="row_heading level0 row6" >School_enrollment_tertiary</th>
#       <td id="T_57489_row6_col0" class="data row6 col0" >0.901717</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row7" class="row_heading level0 row7" >Population_labor_rate</th>
#       <td id="T_57489_row7_col0" class="data row7 col0" >0.865011</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row8" class="row_heading level0 row8" >Population_density</th>
#       <td id="T_57489_row8_col0" class="data row8 col0" >0.848829</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row9" class="row_heading level0 row9" >Access_electricity</th>
#       <td id="T_57489_row9_col0" class="data row9 col0" >0.799278</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row10" class="row_heading level0 row10" >Industry_value_added_current_USD</th>
#       <td id="T_57489_row10_col0" class="data row10 col0" >0.868277</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row11" class="row_heading level0 row11" >Employment_in_industry_%_of_total_employment</th>
#       <td id="T_57489_row11_col0" class="data row11 col0" >0.760334</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row12" class="row_heading level0 row12" >GDP_per_capita_current_USD</th>
#       <td id="T_57489_row12_col0" class="data row12 col0" >0.861350</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row13" class="row_heading level0 row13" >Final_consumption</th>
#       <td id="T_57489_row13_col0" class="data row13 col0" >0.856127</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row14" class="row_heading level0 row14" >Educational_attainment</th>
#       <td id="T_57489_row14_col0" class="data row14 col0" >0.987290</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row15" class="row_heading level0 row15" >Individuals_using_the_Internet_%_of_population</th>
#       <td id="T_57489_row15_col0" class="data row15 col0" >0.937999</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row16" class="row_heading level0 row16" >Poverty_headcount_ratio</th>
#       <td id="T_57489_row16_col0" class="data row16 col0" >-0.929764</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row17" class="row_heading level0 row17" >New_business_density</th>
#       <td id="T_57489_row17_col0" class="data row17 col0" >0.953793</td>
#     </tr>
#     <tr>
#       <th id="T_57489_level0_row18" class="row_heading level0 row18" >Services_value_added_%_of_GDP</th>
#       <td id="T_57489_row18_col0" class="data row18 col0" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
import plotly.graph_objects as go

target = 'Services_value_added_%_of_GDP'
df = s_dfs['CHN']
df = df.drop(['Access_finance', 'Educational_attainment'] , axis =1)
corr = df.replace('..', np.nan).corr()
corr = corr.drop([target], axis = 0)

argmin = corr[target].nsmallest(2)[-1]
argmax = corr[target].nlargest(3)[-1]
step = (argmax-argmin)/10
conditions = [(corr[target]<i) & (corr[target]>=i-step) for i in np.arange(argmin, argmax+step, step)]
conditions.insert(-1, (corr[target]>=argmax))
conditions.insert(0, (corr[target]<=argmin))
cmap = sns.color_palette('coolwarm',13).as_hex()[:]
colors = np.select(conditions, cmap)
colors[0] = '#c83836'
fig = go.Figure(data=[go.Table(
    header=dict(values=['<b>Variables</b>', '<b>	Services_value_added_%_of_GDP</b>'],
                line_color='darkslategray',
                fill_color='white',
                height=29,
                align=['left', 'center']),
    cells=dict(values=round(corr[['Services_value_added_%_of_GDP']],4).reset_index().values[:-1,:].T,
               line_color='darkslategray',
               font=dict(color='black'),
               fill_color=[colors],
               height=33,
               align=['left', 'center'])),
])

fig.update_layout(width=700, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3a9d023d-3634-494f-be93-e7482e2a57d7" class="plotly-graph-div" style="height:800px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a9d023d-3634-494f-be93-e7482e2a57d7")) {                    Plotly.newPlot(                        "3a9d023d-3634-494f-be93-e7482e2a57d7",                        [{"cells":{"align":["left","center"],"fill":{"color":[["#c83836","#9abbff","#f08a6c","#edd1c2","#cd423b","#f08a6c","#cd423b","#cd423b","#cd423b","#f08a6c","#cd423b","#f08a6c","#cd423b","#cd423b","#506bda","#e26952","#506bda","#e26952"]]},"font":{"color":"black"},"height":33,"line":{"color":"darkslategray"},"values":[["Employment_in_services_male","Urban_population_growth","Net_trade_in_goods_services","Foreign_direct_investment","Mobile_cellular_subscriptions","Secure_Internet_servers","School_enrollment_tertiary","Population_labor_rate","Population_density","Access_electricity","Industry_value_added_current_USD","Employment_in_industry_%_of_total_employment","GDP_per_capita_current_USD","Final_consumption","Primary_completion_rate","Individuals_using_the_Internet_%_of_population","Poverty_headcount_ratio"],[0.9679,-0.1549,0.7673,0.3327,0.8616,0.7438,0.9017,0.865,0.8488,0.7993,0.8683,0.7603,0.8613,0.8561,-0.3627,0.938,-0.9298]]},"header":{"align":["left","center"],"fill":{"color":"white"},"height":29,"line":{"color":"darkslategray"},"values":["<b>Variables</b>","<b>\tServices_value_added_%_of_GDP</b>"]},"type":"table"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777 ...
